# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
df=sns.load_dataset('healthexp')
df
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
np.cov(df[['Year', 'Spending_USD', 'Life_Expectancy']])
# Out:
# array([[ 1.09853246e+06,  1.11338028e+06,  1.13093049e+06, ...,
#         -9.49023888e+04, -6.01204227e+03, -1.84486063e+06],
#        [ 1.11338028e+06,  1.12946778e+06,  1.14839981e+06, ...,
#         -1.76328732e+05, -8.02178708e+04, -2.06533966e+06],
#        [ 1.13093049e+06,  1.14839981e+06,  1.16887319e+06, ...,
#         -2.66135928e+05, -1.61973986e+05, -2.31023599e+06],
#        ...,
#        [-9.49023888e+04, -1.76328732e+05, -2.66135928e+05, ...,
#          6.19017612e+06,  5.71820875e+06,  1.52428872e+07],
#        [-6.01204227e+03, -8.02178708e+04, -1.61973986e+05, ...,
#          5.71820875e+06,  5.28830381e+06,  1.39607817e+07],
#        [-1.84486063e+06, -2.06533966e+06, -2.31023599e+06, ...,
#          1.52428872e+07,  1.39607817e+07,  3.99007391e+07]])

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\pwskill\feature_scaling\data_encoding\covaration_and_correlation.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/pwskill/feature_scaling/data_encoding/covaration_and_correlation.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> df.corr()
#
# File c:\Users\kumar\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\kumar\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...
